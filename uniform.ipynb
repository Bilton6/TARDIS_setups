# %%
from tardis.io.atom_data import download_atom_data
from tardis import run_tardis
from tardis.io.atom_data.base import AtomData
from tardis.simulation import Simulation
import matplotlib.pyplot as plt
from tardis.visualization import SDECPlotter
import matplotlib
import numpy as np
import pandas as pd
import os
import re
import csv
from astropy import units as u
from astropy.cosmology import Planck18 as cosmo
from scipy.signal import find_peaks
import periodictable
download_atom_data('kurucz_cd23_chianti_H_He')
# Out:
# Iterations:          0/? [00:00<?, ?it/s]
# Packets:             0/? [00:00<?, ?it/s]
# Atomic Data kurucz_cd23_chianti_H_He already exists in /Users/ncutransient/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5. Will not download - override with force_download=True.

# %% [markdown]
# # Running the Simulation

# %%
# Labels of 03fg-like SNe

hvf1, hvf2, dn12, dc09, aa11 = 'SN2020hvf (-10.4)', 'SN2020hvf (-3.3)', 'SN2012dn (-2.3)', 'SN2009dc (+5.8)', 'SN2011aa (+8.1)'

z_hvf, z_dn12, z_dc09, z_aa11 = 0.0057, 0.0102, 0.0214, 0.0124    # <------------------------------------  redshift

#------------ Enter the information -----------------------------

obj = hvf2
identifier="2020hvf_2"
filename = 'sn2020hvf_2.flm'
z = z_hvf

#----------------------------------------------------------------------------------

d_mpc = cosmo.comoving_distance(z).value
d_cm = (d_mpc * u.Mpc).to(u.cm)
d_term = (4 * np.pi * d_cm**2)

sim = run_tardis(f"{identifier}.yml", virtual_packet_logging=True)


matplotlib.rc('xtick', labelsize=28)
matplotlib.rc('ytick', labelsize=28)
plt.rc('font', size=28)
plt.figure(figsize=(16, 12))

#----------------------------------------

spectrum = np.loadtxt(filename)

obj_wave = spectrum[:, 0] 
obj_flux = spectrum[:, 1]  

wavelength = sim.spectrum_solver.spectrum_integrated.wavelength.to('angstrom').value
lum_density = sim.spectrum_solver.spectrum_integrated.luminosity_density_lambda.value

model_wave = np.array(wavelength)
model_lum_density = np.array(lum_density)
model_flux = model_lum_density / d_term

# Plotting UV + Optical -----------------------

plt.xlabel('Rest wavelength ($\AA$)')
plt.ylabel('$F_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{cm^{-2}}$ $\\mathrm{\\AA^{-1}}$]')
plt.xlim(2500, 8000)
#plt.ylim(0, 1.6e-14)
plt.plot(obj_wave,obj_flux,label=obj, color='blue', linewidth=3)
plt.plot(model_wave,3.2*model_flux,label='TARDIS Spectrum', color='red', linewidth=3)
plt.legend()
plt.tight_layout()
plt.title("UV + Optical")
#plt.savefig(f"{identifier}_opt.pdf")
plt.show()

#-------- Plotting the UV region -----------------

plt.figure(figsize=(16, 12))

plt.xlabel('Rest wavelength ($\AA$)')
plt.ylabel('$F_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{cm^{-2}}$ $\\mathrm{\\AA^{-1}}$]')
plt.xlim(2500, 4500)
#plt.ylim(0, 1.6e-14)
plt.plot(obj_wave,obj_flux,label=obj, color='blue', linewidth=3)
plt.plot(model_wave,3.2*model_flux,label='TARDIS Spectrum', color='red', linewidth=3)
#plt.legend()
plt.tight_layout()
plt.title("UV")
#plt.savefig(f"{identifier}_uv.pdf")
plt.show()

"""
line_list = sim.plasma.lines
line_list_reset = line_list.reset_index()

f_lu_threshold = 0.5

filtered_lines = line_list_reset[
    (line_list_reset['f_lu'] >= f_lu_threshold) &
    (line_list_reset['wavelength'] >= 2500) & 
    (line_list_reset['wavelength'] <= 4500)
]

def get_element_name(atomic_number):
    try:
        return periodictable.elements[atomic_number].name
    except IndexError:
        return None  # Return None for invalid atomic numbers

# Apply the function to get element names
filtered_lines['element_name'] = filtered_lines['atomic_number'].apply(get_element_name)

# Select the desired columns, including the new element name
output_data = filtered_lines[['atomic_number', 'element_name', 'ion_number', 'wavelength']]

# Sort the DataFrame by atomic_number in ascending order
output_data = output_data.sort_values(by='atomic_number', ascending=True)

# Save to CSV
output_data.to_csv(f"{identifier}.csv", index=False)
"""
# Out:
# <>:44: SyntaxWarning: invalid escape sequence '\A'
# <>:60: SyntaxWarning: invalid escape sequence '\A'
# <>:44: SyntaxWarning: invalid escape sequence '\A'
# <>:60: SyntaxWarning: invalid escape sequence '\A'
# /var/folders/h5/2_9rtrmn04j0qkrf67fp6q7r0000gn/T/ipykernel_897/3200390159.py:44: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel('Rest wavelength ($\AA$)')
# /var/folders/h5/2_9rtrmn04j0qkrf67fp6q7r0000gn/T/ipykernel_897/3200390159.py:60: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel('Rest wavelength ($\AA$)')
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:262)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist_atoms, linelist_molecules (base.py:266)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.io.model.parse_mass_fraction_configuration][WARNING]
# 	Mass fractions have not been normalized to 1. - normalizing (parse_mass_fraction_configuration.py:85)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1382400.0 seconds (decay.py:101)
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 10 (base.py:450)
# [py.warnings         ][WARNING]
# 	/Users/ncutransient/opt/anaconda3/envs/tardis/lib/python3.12/site-packages/tardis/transport/montecarlo/montecarlo_main_loop.py:123: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   vpacket_collection = vpacket_collections[i]
#  (warnings.py:112)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.104e+43 erg / s
# 	Luminosity absorbed  = 7.151e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_9c493">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_9c493_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_9c493_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_9c493_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_9c493_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c493_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c493_row0_col0" class="data row0 col0" >1.2e+04 K</td>
#       <td id="T_9c493_row0_col1" class="data row0 col1" >1.22e+04 K</td>
#       <td id="T_9c493_row0_col2" class="data row0 col2" >0.317</td>
#       <td id="T_9c493_row0_col3" class="data row0 col3" >0.353</td>
#     </tr>
#     <tr>
#       <th id="T_9c493_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_9c493_row1_col0" class="data row1 col0" >1.17e+04 K</td>
#       <td id="T_9c493_row1_col1" class="data row1 col1" >1.07e+04 K</td>
#       <td id="T_9c493_row1_col2" class="data row1 col2" >0.0817</td>
#       <td id="T_9c493_row1_col3" class="data row1 col3" >0.101</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 12000.000 K
# 	Expected t_inner for next iteration = 11002.305 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.415e+42 erg / s
# 	Luminosity absorbed  = 4.834e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_20def">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_20def_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_20def_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_20def_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_20def_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20def_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20def_row0_col0" class="data row0 col0" >1.22e+04 K</td>
#       <td id="T_20def_row0_col1" class="data row0 col1" >1.22e+04 K</td>
#       <td id="T_20def_row0_col2" class="data row0 col2" >0.353</td>
#       <td id="T_20def_row0_col3" class="data row0 col3" >0.344</td>
#     </tr>
#     <tr>
#       <th id="T_20def_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_20def_row1_col0" class="data row1 col0" >1.07e+04 K</td>
#       <td id="T_20def_row1_col1" class="data row1 col1" >9.84e+03 K</td>
#       <td id="T_20def_row1_col2" class="data row1 col2" >0.101</td>
#       <td id="T_20def_row1_col3" class="data row1 col3" >0.113</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11002.305 K
# 	Expected t_inner for next iteration = 10754.417 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.777e+42 erg / s
# 	Luminosity absorbed  = 4.395e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_21bdb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_21bdb_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_21bdb_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_21bdb_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_21bdb_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21bdb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21bdb_row0_col0" class="data row0 col0" >1.22e+04 K</td>
#       <td id="T_21bdb_row0_col1" class="data row0 col1" >1.21e+04 K</td>
#       <td id="T_21bdb_row0_col2" class="data row0 col2" >0.344</td>
#       <td id="T_21bdb_row0_col3" class="data row0 col3" >0.333</td>
#     </tr>
#     <tr>
#       <th id="T_21bdb_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_21bdb_row1_col0" class="data row1 col0" >9.84e+03 K</td>
#       <td id="T_21bdb_row1_col1" class="data row1 col1" >9.31e+03 K</td>
#       <td id="T_21bdb_row1_col2" class="data row1 col2" >0.113</td>
#       <td id="T_21bdb_row1_col3" class="data row1 col3" >0.118</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10754.417 K
# 	Expected t_inner for next iteration = 10718.541 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.837e+42 erg / s
# 	Luminosity absorbed  = 4.217e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_46f27">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_46f27_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_46f27_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_46f27_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_46f27_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46f27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46f27_row0_col0" class="data row0 col0" >1.21e+04 K</td>
#       <td id="T_46f27_row0_col1" class="data row0 col1" >1.2e+04 K</td>
#       <td id="T_46f27_row0_col2" class="data row0 col2" >0.333</td>
#       <td id="T_46f27_row0_col3" class="data row0 col3" >0.329</td>
#     </tr>
#     <tr>
#       <th id="T_46f27_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_46f27_row1_col0" class="data row1 col0" >9.31e+03 K</td>
#       <td id="T_46f27_row1_col1" class="data row1 col1" >8.93e+03 K</td>
#       <td id="T_46f27_row1_col2" class="data row1 col2" >0.118</td>
#       <td id="T_46f27_row1_col3" class="data row1 col3" >0.124</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10718.541 K
# 	Expected t_inner for next iteration = 10662.573 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.735e+42 erg / s
# 	Luminosity absorbed  = 4.148e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_f45bd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_f45bd_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_f45bd_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_f45bd_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_f45bd_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f45bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f45bd_row0_col0" class="data row0 col0" >1.2e+04 K</td>
#       <td id="T_f45bd_row0_col1" class="data row0 col1" >1.19e+04 K</td>
#       <td id="T_f45bd_row0_col2" class="data row0 col2" >0.329</td>
#       <td id="T_f45bd_row0_col3" class="data row0 col3" >0.325</td>
#     </tr>
#     <tr>
#       <th id="T_f45bd_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_f45bd_row1_col0" class="data row1 col0" >8.93e+03 K</td>
#       <td id="T_f45bd_row1_col1" class="data row1 col1" >8.74e+03 K</td>
#       <td id="T_f45bd_row1_col2" class="data row1 col2" >0.124</td>
#       <td id="T_f45bd_row1_col3" class="data row1 col3" >0.126</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10662.573 K
# 	Expected t_inner for next iteration = 10641.414 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 6 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.662e+42 erg / s
# 	Luminosity absorbed  = 4.137e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_16f25">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_16f25_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_16f25_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_16f25_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_16f25_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16f25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16f25_row0_col0" class="data row0 col0" >1.19e+04 K</td>
#       <td id="T_16f25_row0_col1" class="data row0 col1" >1.19e+04 K</td>
#       <td id="T_16f25_row0_col2" class="data row0 col2" >0.325</td>
#       <td id="T_16f25_row0_col3" class="data row0 col3" >0.325</td>
#     </tr>
#     <tr>
#       <th id="T_16f25_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_16f25_row1_col0" class="data row1 col0" >8.74e+03 K</td>
#       <td id="T_16f25_row1_col1" class="data row1 col1" >8.62e+03 K</td>
#       <td id="T_16f25_row1_col2" class="data row1 col2" >0.126</td>
#       <td id="T_16f25_row1_col3" class="data row1 col3" >0.127</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10641.414 K
# 	Expected t_inner for next iteration = 10645.568 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 7 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.701e+42 erg / s
# 	Luminosity absorbed  = 4.170e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_97876">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_97876_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_97876_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_97876_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_97876_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97876_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97876_row0_col0" class="data row0 col0" >1.19e+04 K</td>
#       <td id="T_97876_row0_col1" class="data row0 col1" >1.18e+04 K</td>
#       <td id="T_97876_row0_col2" class="data row0 col2" >0.325</td>
#       <td id="T_97876_row0_col3" class="data row0 col3" >0.327</td>
#     </tr>
#     <tr>
#       <th id="T_97876_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_97876_row1_col0" class="data row1 col0" >8.62e+03 K</td>
#       <td id="T_97876_row1_col1" class="data row1 col1" >8.57e+03 K</td>
#       <td id="T_97876_row1_col2" class="data row1 col2" >0.127</td>
#       <td id="T_97876_row1_col3" class="data row1 col3" >0.127</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10645.568 K
# 	Expected t_inner for next iteration = 10636.315 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 8 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.707e+42 erg / s
# 	Luminosity absorbed  = 4.125e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_873e9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_873e9_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_873e9_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_873e9_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_873e9_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_873e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_873e9_row0_col0" class="data row0 col0" >1.18e+04 K</td>
#       <td id="T_873e9_row0_col1" class="data row0 col1" >1.18e+04 K</td>
#       <td id="T_873e9_row0_col2" class="data row0 col2" >0.327</td>
#       <td id="T_873e9_row0_col3" class="data row0 col3" >0.326</td>
#     </tr>
#     <tr>
#       <th id="T_873e9_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_873e9_row1_col0" class="data row1 col0" >8.57e+03 K</td>
#       <td id="T_873e9_row1_col1" class="data row1 col1" >8.57e+03 K</td>
#       <td id="T_873e9_row1_col2" class="data row1 col2" >0.127</td>
#       <td id="T_873e9_row1_col3" class="data row1 col3" >0.126</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10636.315 K
# 	Expected t_inner for next iteration = 10624.669 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 9 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.688e+42 erg / s
# 	Luminosity absorbed  = 4.117e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_0f5ce">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_0f5ce_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_0f5ce_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_0f5ce_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_0f5ce_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f5ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f5ce_row0_col0" class="data row0 col0" >1.18e+04 K</td>
#       <td id="T_0f5ce_row0_col1" class="data row0 col1" >1.18e+04 K</td>
#       <td id="T_0f5ce_row0_col2" class="data row0 col2" >0.326</td>
#       <td id="T_0f5ce_row0_col3" class="data row0 col3" >0.327</td>
#     </tr>
#     <tr>
#       <th id="T_0f5ce_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_0f5ce_row1_col0" class="data row1 col0" >8.57e+03 K</td>
#       <td id="T_0f5ce_row1_col1" class="data row1 col1" >8.58e+03 K</td>
#       <td id="T_0f5ce_row1_col2" class="data row1 col2" >0.126</td>
#       <td id="T_0f5ce_row1_col3" class="data row1 col3" >0.125</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10624.669 K
# 	Expected t_inner for next iteration = 10619.833 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 9 iterations
# 	Simulation took 73.04 s
#  (base.py:548)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 10 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.720e+42 erg / s
# 	Luminosity absorbed  = 4.080e+42 erg / s
# 	Luminosity requested = 7.674e+42 erg / s
#  (base.py:663)
# '\nline_list = sim.plasma.lines\nline_list_reset = line_list.reset_index()\n\nf_lu_threshold = 0.5\n\nfiltered_lines = line_list_reset[\n    (line_list_reset[\'f_lu\'] >= f_lu_threshold) &\n    (line_list_reset[\'wavelength\'] >= 2500) & \n    (line_list_reset[\'wavelength\'] <= 4500)\n]\n\ndef get_element_name(atomic_number):\n    try:\n        return periodictable.elements[atomic_number].name\n    except IndexError:\n        return None  # Return None for invalid atomic numbers\n\n# Apply the function to get element names\nfiltered_lines[\'element_name\'] = filtered_lines[\'atomic_number\'].apply(get_element_name)\n\n# Select the desired columns, including the new element name\noutput_data = filtered_lines[[\'atomic_number\', \'element_name\', \'ion_number\', \'wavelength\']]\n\n# Sort the DataFrame by atomic_number in ascending order\noutput_data = output_data.sort_values(by=\'atomic_number\', ascending=True)\n\n# Save to CSV\noutput_data.to_csv(f"{identifier}.csv", index=False)\n'

# %% [markdown]
# # Element plot UV

# %%
spectrum = np.loadtxt(filename)

obj_mask = (spectrum[:, 0] >= 2500) & (spectrum[:, 0] <= 4500)
obj_wave = spectrum[obj_mask, 0]
obj_flux = spectrum[obj_mask, 1]


matplotlib.rc('xtick', labelsize=44)
matplotlib.rc('ytick', labelsize=44)
figsize = (28, 20)

plotter = SDECPlotter.from_simulation(sim)
observed_spectrum_wavelength = obj_wave * u.AA 
observed_spectrum_flux = 0.3*obj_flux * u.erg / (u.s * u.cm**2 * u.AA)

plotter.generate_plot_mpl(observed_spectrum = (observed_spectrum_wavelength, observed_spectrum_flux), 
                          distance = d_mpc * u.Mpc,blackbody_photosphere=False,cmapname='Paired',
                          packet_wvl_range=[2500, 4500] * u.AA,nelements=12,figsize=figsize)


observed_line = plt.gca().get_lines()[-1]
observed_line.set_linewidth(3)
observed_line.set_label(obj)

cbar = plt.gcf().axes[-1]  # Get the colorbar axes
cbar.tick_params(labelsize=56)  # Adjust the font size as needed

plt.legend(fontsize=38,loc='lower right', frameon=False)
plt.xlabel('Rest wavelength ($\AA$)',fontsize=46)
plt.ylabel('$F_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{cm^{-2}}$ $\\mathrm{\\AA^{-1}}$]',fontsize=46)
plt.tight_layout()
plt.savefig(f"sed_{identifier}.pdf")
# Out:
# [py.warnings         ][WARNING]
# 	<>:29: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	<>:29: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	/var/folders/h5/2_9rtrmn04j0qkrf67fp6q7r0000gn/T/ipykernel_98560/363343475.py:29: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel('Rest wavelength ($\AA$)',fontsize=46)
#  (warnings.py:112)

# %% [markdown]
# # Element Plot Optical

# %%
spectrum = np.loadtxt(filename)

obj_mask2 = (spectrum[:, 0] >= 4000) & (spectrum[:, 0] <= 8000)
obj_wave = spectrum[obj_mask2, 0]
obj_flux = spectrum[obj_mask2, 1]

figsize = (16, 10)
plotter = SDECPlotter.from_simulation(sim)
observed_spectrum_wavelength = obj_wave * u.AA 
observed_spectrum_flux = 0.3*obj_flux * u.erg / (u.s * u.cm**2 * u.AA)


plotter.generate_plot_mpl( distance = d_mpc * u.Mpc,blackbody_photosphere=False,cmapname='Paired',
                          packet_wvl_range=[4000, 8000] * u.AA,figsize=figsize)
                     


plt.legend(fontsize=12,loc='upper right')

plt.savefig(f"sed_{identifier}_optical.pdf")

# %%
plotter = SDECPlotter.from_simulation(sim)
plotter.generate_plot_mpl( blackbody_photosphere=False, species_list = ['Mg II', 'Ti I', 'Co II', 'Fe III'])
# Out:
# <Axes: xlabel='Wavelength $[\\mathrm{\\AA}]$', ylabel='$L_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{\\AA^{-1}}$]'>
