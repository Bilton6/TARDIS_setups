# %%
from tardis.io.atom_data import download_atom_data
from tardis import run_tardis
from tardis.io.atom_data.base import AtomData
from tardis.simulation import Simulation
import matplotlib.pyplot as plt
from tardis.visualization import SDECPlotter
import matplotlib
import numpy as np
import pandas as pd
import os
import re
import csv
from astropy import units as u
from astropy.cosmology import Planck18 as cosmo
from scipy.signal import find_peaks
download_atom_data('kurucz_cd23_chianti_H_He')
# Out:
# Iterations:          0/? [00:00<?, ?it/s]
# Packets:             0/? [00:00<?, ?it/s]
# Atomic Data kurucz_cd23_chianti_H_He already exists in /Users/ncutransient/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5. Will not download - override with force_download=True.

# %% [markdown]
# # Running the Simulation

# %%
# Labels of 03fg-like SNe

hvf1, hvf2, dn12, dc09, aa11, fe11 = 'SN2020hvf (-10.4)', 'SN2020hvf (-3.3)', 'SN2012dn (-2.3)', 'SN2009dc (+5.8)', 'SN2011aa (+8.1)', 'SN2011fe (-3.3)'

z_hvf, z_dn12, z_dc09, z_aa11, z_fe11 = 0.0057, 0.0102, 0.0214, 0.0124, 0.0008    # <------------------------------------  redshift

#------------ Information of the Object -----------------------------

obj = fe11
identifier="2011fe"
filename = 'sn2011fe.flm'
z = z_fe11

#----------------------------------------------------------------------------------

d_mpc = cosmo.comoving_distance(z).value
d_cm = (d_mpc * u.Mpc).to(u.cm)
d_term = (4 * np.pi * d_cm**2)

sim = run_tardis(f"{identifier}.yml", virtual_packet_logging=True)

#---------------------------------

matplotlib.rc('xtick', labelsize=30)
matplotlib.rc('ytick', labelsize=30)
plt.rc('font', size=32)
plt.figure(figsize=(16, 12))

plt.rc('xtick.major', size=14, width=4)  # Major ticks
plt.rc('ytick.major', size=14, width=4)
plt.rc('xtick.minor', size=7, width=2)  # Minor ticks
plt.rc('ytick.minor', size=7, width=2)

# Enable minor ticks globally
plt.rc('xtick', top=True, direction='in')
plt.rc('ytick', right=True, direction='in')

plt.rc('xtick.minor', visible=True)
plt.rc('ytick.minor', visible=True)

#----------------------------------------

spectrum = np.loadtxt(filename)

obj_wave = spectrum[:, 0] 
obj_flux = spectrum[:, 1]  

wavelength = sim.spectrum_solver.spectrum_integrated.wavelength.to('angstrom').value
lum_density = sim.spectrum_solver.spectrum_integrated.luminosity_density_lambda.value

model_wave = np.array(wavelength)
model_lum_density = np.array(lum_density)
model_flux = model_lum_density / d_term

# Plotting UV + Optical -----------------------

plt.xlabel('Rest wavelength ($\AA$)')
plt.ylabel('$F_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{cm^{-2}}$ $\\mathrm{\\AA^{-1}}$]')
plt.xlim(2500, 8000)
#plt.ylim(0, 5.5e-14)
plt.plot(obj_wave,obj_flux,label=obj, color='blue', linewidth=3,alpha=0.7)
plt.plot(model_wave,.8*model_flux,label='TARDIS Spectrum', color='red', linewidth=4)
plt.legend()
plt.tight_layout()
plt.title("UV + Optical")
plt.savefig(f"{identifier}_opt.pdf")
plt.show()

#-------- Plotting the UV region -----------------

plt.figure(figsize=(16, 12))

plt.xlabel('Rest wavelength ($\AA$)')
plt.ylabel('$F_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{cm^{-2}}$ $\\mathrm{\\AA^{-1}}$]')
plt.xlim(2500, 4500)
#plt.ylim(0, 5.5e-14)
plt.plot(obj_wave,obj_flux,label=obj, color='blue', linewidth=3,alpha=0.7)
plt.plot(model_wave,.8*model_flux,label='TARDIS Spectrum', color='red', linewidth=4)
plt.legend()
plt.tight_layout()
plt.title("UV")
plt.savefig(f"{identifier}_uv.pdf")
plt.show()
# Out:
# [py.warnings         ][WARNING]
# 	<>:57: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	<>:73: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	<>:57: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	<>:73: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	/var/folders/h5/2_9rtrmn04j0qkrf67fp6q7r0000gn/T/ipykernel_8560/4079512126.py:57: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel('Rest wavelength ($\AA$)')
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	/var/folders/h5/2_9rtrmn04j0qkrf67fp6q7r0000gn/T/ipykernel_8560/4079512126.py:73: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel('Rest wavelength ($\AA$)')
#  (warnings.py:112)
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:262)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist_atoms, linelist_molecules (base.py:266)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.io.model.parse_mass_fraction_configuration][WARNING]
# 	Mass fractions have not been normalized to 1. - normalizing (parse_mass_fraction_configuration.py:85)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1296000.0 seconds (decay.py:101)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 10 (base.py:450)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 2.841e+42 erg / s
# 	Luminosity absorbed  = 2.806e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_5b004">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_5b004_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_5b004_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_5b004_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_5b004_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b004_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b004_row0_col0" class="data row0 col0" >8.99e+03 K</td>
#       <td id="T_5b004_row0_col1" class="data row0 col1" >9.16e+03 K</td>
#       <td id="T_5b004_row0_col2" class="data row0 col2" >0.38</td>
#       <td id="T_5b004_row0_col3" class="data row0 col3" >0.426</td>
#     </tr>
#     <tr>
#       <th id="T_5b004_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_5b004_row1_col0" class="data row1 col0" >8.9e+03 K</td>
#       <td id="T_5b004_row1_col1" class="data row1 col1" >8.66e+03 K</td>
#       <td id="T_5b004_row1_col2" class="data row1 col2" >0.17</td>
#       <td id="T_5b004_row1_col3" class="data row1 col3" >0.177</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9000.000 K
# 	Expected t_inner for next iteration = 9735.359 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.695e+42 erg / s
# 	Luminosity absorbed  = 4.034e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_8dabf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_8dabf_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_8dabf_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_8dabf_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_8dabf_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dabf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dabf_row0_col0" class="data row0 col0" >9.16e+03 K</td>
#       <td id="T_8dabf_row0_col1" class="data row0 col1" >9.47e+03 K</td>
#       <td id="T_8dabf_row0_col2" class="data row0 col2" >0.426</td>
#       <td id="T_8dabf_row0_col3" class="data row0 col3" >0.477</td>
#     </tr>
#     <tr>
#       <th id="T_8dabf_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_8dabf_row1_col0" class="data row1 col0" >8.66e+03 K</td>
#       <td id="T_8dabf_row1_col1" class="data row1 col1" >8.66e+03 K</td>
#       <td id="T_8dabf_row1_col2" class="data row1 col2" >0.177</td>
#       <td id="T_8dabf_row1_col3" class="data row1 col3" >0.191</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9735.359 K
# 	Expected t_inner for next iteration = 9834.121 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.920e+42 erg / s
# 	Luminosity absorbed  = 4.034e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_b4cfe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_b4cfe_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_b4cfe_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_b4cfe_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_b4cfe_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4cfe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4cfe_row0_col0" class="data row0 col0" >9.47e+03 K</td>
#       <td id="T_b4cfe_row0_col1" class="data row0 col1" >9.74e+03 K</td>
#       <td id="T_b4cfe_row0_col2" class="data row0 col2" >0.477</td>
#       <td id="T_b4cfe_row0_col3" class="data row0 col3" >0.5</td>
#     </tr>
#     <tr>
#       <th id="T_b4cfe_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_b4cfe_row1_col0" class="data row1 col0" >8.66e+03 K</td>
#       <td id="T_b4cfe_row1_col1" class="data row1 col1" >8.75e+03 K</td>
#       <td id="T_b4cfe_row1_col2" class="data row1 col2" >0.191</td>
#       <td id="T_b4cfe_row1_col3" class="data row1 col3" >0.202</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9834.121 K
# 	Expected t_inner for next iteration = 9787.253 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.952e+42 erg / s
# 	Luminosity absorbed  = 3.797e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_2835d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_2835d_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_2835d_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_2835d_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_2835d_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2835d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2835d_row0_col0" class="data row0 col0" >9.74e+03 K</td>
#       <td id="T_2835d_row0_col1" class="data row0 col1" >9.96e+03 K</td>
#       <td id="T_2835d_row0_col2" class="data row0 col2" >0.5</td>
#       <td id="T_2835d_row0_col3" class="data row0 col3" >0.499</td>
#     </tr>
#     <tr>
#       <th id="T_2835d_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_2835d_row1_col0" class="data row1 col0" >8.75e+03 K</td>
#       <td id="T_2835d_row1_col1" class="data row1 col1" >8.87e+03 K</td>
#       <td id="T_2835d_row1_col2" class="data row1 col2" >0.202</td>
#       <td id="T_2835d_row1_col3" class="data row1 col3" >0.203</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9787.253 K
# 	Expected t_inner for next iteration = 9721.469 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.927e+42 erg / s
# 	Luminosity absorbed  = 3.540e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_494bf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_494bf_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_494bf_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_494bf_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_494bf_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_494bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_494bf_row0_col0" class="data row0 col0" >9.96e+03 K</td>
#       <td id="T_494bf_row0_col1" class="data row0 col1" >1.01e+04 K</td>
#       <td id="T_494bf_row0_col2" class="data row0 col2" >0.499</td>
#       <td id="T_494bf_row0_col3" class="data row0 col3" >0.491</td>
#     </tr>
#     <tr>
#       <th id="T_494bf_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_494bf_row1_col0" class="data row1 col0" >8.87e+03 K</td>
#       <td id="T_494bf_row1_col1" class="data row1 col1" >9.01e+03 K</td>
#       <td id="T_494bf_row1_col2" class="data row1 col2" >0.203</td>
#       <td id="T_494bf_row1_col3" class="data row1 col3" >0.198</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9721.469 K
# 	Expected t_inner for next iteration = 9671.118 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 6 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.951e+42 erg / s
# 	Luminosity absorbed  = 3.374e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_d54dc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_d54dc_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_d54dc_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_d54dc_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_d54dc_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d54dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d54dc_row0_col0" class="data row0 col0" >1.01e+04 K</td>
#       <td id="T_d54dc_row0_col1" class="data row0 col1" >1.02e+04 K</td>
#       <td id="T_d54dc_row0_col2" class="data row0 col2" >0.491</td>
#       <td id="T_d54dc_row0_col3" class="data row0 col3" >0.478</td>
#     </tr>
#     <tr>
#       <th id="T_d54dc_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_d54dc_row1_col0" class="data row1 col0" >9.01e+03 K</td>
#       <td id="T_d54dc_row1_col1" class="data row1 col1" >9.12e+03 K</td>
#       <td id="T_d54dc_row1_col2" class="data row1 col2" >0.198</td>
#       <td id="T_d54dc_row1_col3" class="data row1 col3" >0.192</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9671.118 K
# 	Expected t_inner for next iteration = 9606.450 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 7 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.939e+42 erg / s
# 	Luminosity absorbed  = 3.178e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_3a41b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_3a41b_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_3a41b_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_3a41b_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_3a41b_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a41b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a41b_row0_col0" class="data row0 col0" >1.02e+04 K</td>
#       <td id="T_3a41b_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_3a41b_row0_col2" class="data row0 col2" >0.478</td>
#       <td id="T_3a41b_row0_col3" class="data row0 col3" >0.463</td>
#     </tr>
#     <tr>
#       <th id="T_3a41b_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_3a41b_row1_col0" class="data row1 col0" >9.12e+03 K</td>
#       <td id="T_3a41b_row1_col1" class="data row1 col1" >9.19e+03 K</td>
#       <td id="T_3a41b_row1_col2" class="data row1 col2" >0.192</td>
#       <td id="T_3a41b_row1_col3" class="data row1 col3" >0.186</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9606.450 K
# 	Expected t_inner for next iteration = 9549.312 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 8 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.937e+42 erg / s
# 	Luminosity absorbed  = 3.016e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_a8c44">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_a8c44_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_a8c44_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_a8c44_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_a8c44_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8c44_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8c44_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_a8c44_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_a8c44_row0_col2" class="data row0 col2" >0.463</td>
#       <td id="T_a8c44_row0_col3" class="data row0 col3" >0.448</td>
#     </tr>
#     <tr>
#       <th id="T_a8c44_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_a8c44_row1_col0" class="data row1 col0" >9.19e+03 K</td>
#       <td id="T_a8c44_row1_col1" class="data row1 col1" >9.23e+03 K</td>
#       <td id="T_a8c44_row1_col2" class="data row1 col2" >0.186</td>
#       <td id="T_a8c44_row1_col3" class="data row1 col3" >0.181</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9549.312 K
# 	Expected t_inner for next iteration = 9493.539 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 9 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.872e+42 erg / s
# 	Luminosity absorbed  = 2.949e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:631)
# <style type="text/css">
# </style>
# <table id="T_6bfb1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_6bfb1_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_6bfb1_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_6bfb1_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_6bfb1_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bfb1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bfb1_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_6bfb1_row0_col1" class="data row0 col1" >1.04e+04 K</td>
#       <td id="T_6bfb1_row0_col2" class="data row0 col2" >0.448</td>
#       <td id="T_6bfb1_row0_col3" class="data row0 col3" >0.435</td>
#     </tr>
#     <tr>
#       <th id="T_6bfb1_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_6bfb1_row1_col0" class="data row1 col0" >9.23e+03 K</td>
#       <td id="T_6bfb1_row1_col1" class="data row1 col1" >9.33e+03 K</td>
#       <td id="T_6bfb1_row1_col2" class="data row1 col2" >0.181</td>
#       <td id="T_6bfb1_row1_col3" class="data row1 col3" >0.172</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9493.539 K
# 	Expected t_inner for next iteration = 9477.875 K
#  (base.py:658)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 9 iterations
# 	Simulation took 20.65 s
#  (base.py:548)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 10 of 10 (base.py:450)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 3.869e+42 erg / s
# 	Luminosity absorbed  = 2.868e+42 erg / s
# 	Luminosity requested = 3.846e+42 erg / s
#  (base.py:663)

# %% [markdown]
# # SED plot UV

# %%
spectrum = np.loadtxt(filename)

obj_mask = (spectrum[:, 0] >= 2500) & (spectrum[:, 0] <= 4500)
obj_wave = spectrum[obj_mask, 0]
obj_flux = spectrum[obj_mask, 1]


matplotlib.rc('xtick', labelsize=50)
matplotlib.rc('ytick', labelsize=50)
plt.rc('font', size=32)
figsize = (28, 20)

plt.rc('xtick.major', size=20, width=5)  # Major ticks
plt.rc('ytick.major', size=20, width=5)
plt.rc('xtick.minor', size=10, width=3)  # Minor ticks
plt.rc('ytick.minor', size=10, width=3)

# Enable minor ticks globally
plt.rc('xtick', top=True, direction='in')
plt.rc('ytick', right=True, direction='in')

plt.rc('xtick.minor', visible=True)
plt.rc('ytick.minor', visible=True)

plotter = SDECPlotter.from_simulation(sim)
observed_spectrum_wavelength = obj_wave * u.AA 
observed_spectrum_flux = 1.2*obj_flux * u.erg / (u.s * u.cm**2 * u.AA)

plotter.generate_plot_mpl(observed_spectrum = (observed_spectrum_wavelength, observed_spectrum_flux), 
                          distance = d_mpc * u.Mpc,blackbody_photosphere=False,cmapname='Paired',
                          packet_wvl_range=[2500, 4500] * u.AA,nelements=12,figsize=figsize)


observed_line = plt.gca().get_lines()[-1]
observed_line.set_linewidth(3)
observed_line.set_label(obj)

cbar = plt.gcf().axes[-1] 
cbar.tick_params(labelsize=56, which='both', length=0)  # Hide tick marks

plt.legend(fontsize=38,loc='lower right', frameon=False)
plt.xlabel('Rest wavelength ($\AA$)',fontsize=46)
plt.ylabel('$F_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{cm^{-2}}$ $\\mathrm{\\AA^{-1}}$]',fontsize=46)
plt.tight_layout()
plt.savefig(f"sed_{identifier}.pdf")
# Out:
# [py.warnings         ][WARNING]
# 	<>:42: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	<>:42: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	/var/folders/h5/2_9rtrmn04j0qkrf67fp6q7r0000gn/T/ipykernel_8560/3660088802.py:42: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel('Rest wavelength ($\AA$)',fontsize=46)
#  (warnings.py:112)

# %% [markdown]
# # SED Plot Optical

# %%
spectrum = np.loadtxt(filename)

obj_mask2 = (spectrum[:, 0] >= 4000) & (spectrum[:, 0] <= 8000)
obj_wave = spectrum[obj_mask2, 0]
obj_flux = spectrum[obj_mask2, 1]

figsize = (16, 10)
plotter = SDECPlotter.from_simulation(sim)
observed_spectrum_wavelength = obj_wave * u.AA 
observed_spectrum_flux = 0.3*obj_flux * u.erg / (u.s * u.cm**2 * u.AA)


plotter.generate_plot_mpl( distance = d_mpc * u.Mpc,blackbody_photosphere=False,cmapname='Paired',
                          packet_wvl_range=[4000, 8000] * u.AA,figsize=figsize)
                     


plt.legend(fontsize=12,loc='upper right')

plt.savefig(f"sed_{identifier}_optical.pdf")

# %% [markdown]
# # --------------------------------------------------------

# %%
matplotlib.rc('xtick', labelsize=28)
matplotlib.rc('ytick', labelsize=28)
plt.rc('font', size=28)
plt.figure(figsize=(16, 12))

#----------------------------------------

spectrum = np.loadtxt(filename)

obj_wave = spectrum[:, 0] 
obj_flux = spectrum[:, 1]  

wavelength = sim.spectrum_solver.spectrum_integrated.wavelength.to('angstrom').value
lum_density = sim.spectrum_solver.spectrum_integrated.luminosity_density_lambda.value

model_wave = np.array(wavelength)
model_lum_density = np.array(lum_density)
model_flux = model_lum_density / d_term

# Plotting UV + Optical -----------------------

alpha=.3
plt.xlabel('Rest wavelength ($\AA$)')
plt.ylabel('$F_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{cm^{-2}}$ $\\mathrm{\\AA^{-1}}$]')
plt.xlim(2500, 8000)
#plt.ylim(0, 1.6e-14)
plt.plot(obj_wave,obj_flux,label=obj, color='blue', linewidth=3)
plt.plot(model_wave,alpha*model_flux,label='TARDIS Spectrum', color='red', linewidth=3)
plt.legend()
plt.tight_layout()
plt.title("UV + Optical")
plt.savefig(f"{identifier}_opt.pdf")
plt.show()

#-------- Plotting the UV region -----------------

plt.figure(figsize=(16, 12))

plt.xlabel('Rest wavelength ($\AA$)')
plt.ylabel('$F_{\\lambda}$ [erg $\\mathrm{s^{-1}}$ $\\mathrm{cm^{-2}}$ $\\mathrm{\\AA^{-1}}$]')
plt.xlim(2500, 4500)
#plt.ylim(0, 1.6e-14)
plt.plot(obj_wave,obj_flux,label=obj, color='blue', linewidth=3)
plt.plot(model_wave,alpha*model_flux,label='TARDIS Spectrum', color='red', linewidth=3)
plt.legend()
plt.tight_layout()
plt.title("UV")
plt.savefig(f"{identifier}_uv.pdf")
plt.show()
# Out:
# [py.warnings         ][WARNING]
# 	<>:23: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	<>:39: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	<>:23: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	<>:39: SyntaxWarning: invalid escape sequence '\A'
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	/var/folders/h5/2_9rtrmn04j0qkrf67fp6q7r0000gn/T/ipykernel_39645/413645562.py:23: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel('Rest wavelength ($\AA$)')
#  (warnings.py:112)
# [py.warnings         ][WARNING]
# 	/var/folders/h5/2_9rtrmn04j0qkrf67fp6q7r0000gn/T/ipykernel_39645/413645562.py:39: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel('Rest wavelength ($\AA$)')
#  (warnings.py:112)
